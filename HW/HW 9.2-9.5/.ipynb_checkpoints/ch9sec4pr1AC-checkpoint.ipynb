# %%
'''
Animesh Chaudhry 
HW 3
Math 440 
10/20/2019
Ch 9  Section 4 Problem 1
'''
# Out:
# '\nAnimesh Chaudhry \nHW 3\nMath 440 \n10/20/2019\nCh 9  Section 4 Problem 1 and 2\n'

# %%
'''
Use Householder’s method to produce a symmetric tridiagonal matrix that is similar to the given
matrix.
'''
import numpy as np
from string import ascii_lowercase

def householder(A):
    
    for i in range(len(A)-2):
        alpha = -(A[1][0]/abs(A[1][0]))*(np.sum(A[1:4,0]**2)**.5)
        r = (.5*alpha**2-.5*A[1][0]*alpha)**.5
        w = np.zeros(len(A))
        w[1] = (A[1][0]-alpha)/(2*r)
        for j in range(len(A)-2):
            w[j+2] = (A[j+2][0])/(2*r)
        wt = w.reshape(len(A),1)
        P = np.eye(len(A))-2*wt*w
        A = np.matmul(P,np.matmul(A,P))
    
    return np.round(A,5)


a = np.array([[12, 10, 4], [10,8,-5],[4,-5,3]])
b = np.array([[2, -1, -1], [-1,2,-1],[-1,-1,2]])
c = np.array([[1, 1, 1], [1,1, 0],[1,0,1]])
d = np.array([[4.75, 2.25, -0.25], [2.25,4.75,1.25],[-0.25,1.25,4.75]])
e = np.array([[4,-1,-1,0], [-1,4,0,-1], [-1,0,4,-1],[0,-1,-1,4]])
f = np.array([[5,-2,-0.5,1.5], [-2,5,1.5,-0.5], [-0.5,1.5,5,-2],[1.5,-0.5,-2,5]])
g = np.array([[8,0.25,0.5,2,-1], [0.24,-4,0,1,2], [0.5,0,5,0.75,-1],[2,1,-.75,5,-0.5], [-1,2,-1,-0.5,6]])
h = np.array([[2,-1,-1,0,0], [-1,3,0,-2,0], [-1,0,4,2,1],[0,-2,2,8,3], [0,0,1,3,9]])

def print_hld(A, part):
    print(f"-------------------------------------------------\n{part}: \n{A}\n \nSymmetric tridiagonal matrix that is similar to {part}: \n{householder(A)}\n-------------------------------------------------\n\n\n")

matrices = [a,b,c,d,e,f,g,h]
for c, i in zip(matrices, ascii_lowercase):
    print_hld(c, i)
# Out:
# -------------------------------------------------
# a:
# [[12 10  4]
#  [10  8 -5]
#  [ 4 -5  3]]
#
# Symmetric tridiagonal matrix that is similar to a:
# [[ 12.      -10.77033   0.     ]
#  [-10.77033   3.86207   5.34483]
#  [  0.        5.34483   7.13793]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# b:
# [[ 2 -1 -1]
#  [-1  2 -1]
#  [-1 -1  2]]
#
# Symmetric tridiagonal matrix that is similar to b:
# [[ 2.       1.41421  0.     ]
#  [ 1.41421  1.      -0.     ]
#  [ 0.      -0.       3.     ]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# c:
# [[1 1 1]
#  [1 1 0]
#  [1 0 1]]
#
# Symmetric tridiagonal matrix that is similar to c:
# [[ 1.      -1.41421  0.     ]
#  [-1.41421  1.      -0.     ]
#  [ 0.      -0.       1.     ]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# d:
# [[ 4.75  2.25 -0.25]
#  [ 2.25  4.75  1.25]
#  [-0.25  1.25  4.75]]
#
# Symmetric tridiagonal matrix that is similar to d:
# [[ 4.75    -2.26385 -0.     ]
#  [-2.26385  4.47561 -1.21951]
#  [-0.      -1.21951  5.02439]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# e:
# [[ 4 -1 -1  0]
#  [-1  4  0 -1]
#  [-1  0  4 -1]
#  [ 0 -1 -1  4]]
#
# Symmetric tridiagonal matrix that is similar to e:
# [[ 4.      -1.41421  0.       0.     ]
#  [-1.41421  4.       0.      -1.41421]
#  [ 0.       0.       4.       0.     ]
#  [ 0.      -1.41421  0.       4.     ]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# f:
# [[ 5.  -2.  -0.5  1.5]
#  [-2.   5.   1.5 -0.5]
#  [-0.5  1.5  5.  -2. ]
#  [ 1.5 -0.5 -2.   5. ]]
#
# Symmetric tridiagonal matrix that is similar to f:
# [[ 5.      -2.54951  0.       0.     ]
#  [-2.54951  6.38462  2.13656 -0.13397]
#  [ 0.       2.13656  4.18395 -0.68116]
#  [ 0.      -0.13397 -0.68116  4.43144]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# g:
# [[ 8.    0.25  0.5   2.   -1.  ]
#  [ 0.24 -4.    0.    1.    2.  ]
#  [ 0.5   0.    5.    0.75 -1.  ]
#  [ 2.    1.   -0.75  5.   -0.5 ]
#  [-1.    2.   -1.   -0.5   6.  ]]
#
# Symmetric tridiagonal matrix that is similar to g:
# [[ 8.00000e+00 -2.61289e+00 -2.32000e-03 -9.29000e-03  4.64000e-03]
#  [-2.60972e+00  6.64562e+00 -2.36900e-02 -1.79873e+00  1.10377e+00]
#  [-0.00000e+00 -1.47157e+00  4.40858e+00 -2.09119e+00  1.46100e-02]
#  [-0.00000e+00 -1.43676e+00 -2.51225e+00 -3.95100e+00  2.35155e+00]
#  [ 0.00000e+00  1.10377e+00 -4.93130e-01  2.47848e+00  5.32273e+00]]
# -------------------------------------------------
#
#
#
# -------------------------------------------------
# h:
# [[ 2 -1 -1  0  0]
#  [-1  3  0 -2  0]
#  [-1  0  4  2  1]
#  [ 0 -2  2  8  3]
#  [ 0  0  1  3  9]]
#
# Symmetric tridiagonal matrix that is similar to h:
# [[ 2.       1.41421  0.       0.       0.     ]
#  [ 1.41421  3.5     -0.5     -0.      -0.70711]
#  [ 0.      -0.5      3.5      2.82843  0.70711]
#  [ 0.      -0.       2.82843  8.       3.     ]
#  [ 0.      -0.70711  0.70711  3.       9.     ]]
# -------------------------------------------------
