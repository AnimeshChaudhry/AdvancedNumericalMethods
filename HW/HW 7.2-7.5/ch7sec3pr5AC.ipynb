# %%
'''

Name: Animesh Chaudhry 

Class: Math 440

Find the || · ||2 norms of the matrices in Exercise 1 (ch7sec3pr1AC).

'''

# %%
from itertools import chain
import math
import pandas as pd
from string import ascii_lowercase



# Example Matrices from the book
a = [[2, -1],
    [-1, 2]]

b = [[0, 1],
    [1, 1]]

c = [[0, 1/2],
    [1/2, 0]]

d = [[1, 1],
    [2, 2]]

e = [[2, 1, 0],
    [1, 2, 0],
    [0, 0, 3]]

f = [[-1, 2, 0],
    [0, 3, 4],
    [0, 0, 7]]

g = [[2, 1, 1],
    [2, 3, 2],
    [1, 1, 2]]

h = [[3, 2, -1],
    [1, -2, 3],
    [2, 0, 4]]




def Matrix_norm_two(mat): 
    mat = list(chain.from_iterable(zip(*mat)))
    s = 0
    for i in mat:
        s+=i**2
    return math.sqrt(s)

def print_norm(part, mat):
    print('Part {} ------------------------------------------------\n{}\n The L2 norm is: {}\n'.format(part, pd.DataFrame(mat), Matrix_norm_two(mat)))
    
matrices = [a,b,c,d,e,f,g,h]
for i, c in zip(matrices, ascii_lowercase):
    print_norm(c, i)
# Out:
# Part a ------------------------------------------------
#    0  1
# 0  2 -1
# 1 -1  2
#  The L2 norm is: 3.1622776601683795
#
# Part b ------------------------------------------------
#    0  1
# 0  0  1
# 1  1  1
#  The L2 norm is: 1.7320508075688772
#
# Part c ------------------------------------------------
#      0    1
# 0  0.0  0.5
# 1  0.5  0.0
#  The L2 norm is: 0.7071067811865476
#
# Part d ------------------------------------------------
#    0  1
# 0  1  1
# 1  2  2
#  The L2 norm is: 3.1622776601683795
#
# Part e ------------------------------------------------
#    0  1  2
# 0  2  1  0
# 1  1  2  0
# 2  0  0  3
#  The L2 norm is: 4.358898943540674
#
# Part f ------------------------------------------------
#    0  1  2
# 0 -1  2  0
# 1  0  3  4
# 2  0  0  7
#  The L2 norm is: 8.888194417315589
#
# Part g ------------------------------------------------
#    0  1  2
# 0  2  1  1
# 1  2  3  2
# 2  1  1  2
#  The L2 norm is: 5.385164807134504
#
# ...
