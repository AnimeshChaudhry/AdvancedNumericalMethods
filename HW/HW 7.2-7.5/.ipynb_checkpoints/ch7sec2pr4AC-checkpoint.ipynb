# %%
'''
Name: Animesh Chaudhry 

Class: Math 440

Questions: Find ||*||oo for Matrices
'''

# Examples
a = [[10, 15],
    [0, 1]]

b = [[10, 0],
    [15, 1]]

c = [[2, -1, 0],
    [-1, 2, -1],
    [0, -1, 2]]

d = [[4, -1, 7],
    [-1, 4, 0],
    [-7, 0, 4]]




import numpy as np
import pandas as pd
from string import ascii_lowercase

def get_Matrix():
    n=int(input("Enter the matrix size "))
    
    #initialise nxn matrix with zeroes
    mat=np.zeros((n,n))
    
    #input each row at a time,with each element separated by a space
    for i in range(n):
        mat[i]=input().split(" ")
    return mat

def print_answer(part, mat):
    print('{}\n Part {} - The infinity norm of the above matrix is: {}\n'.format(pd.DataFrame(mat), part, Matrix_norm(mat)))


def Matrix_norm(A):
    n, l = len(A), []          
    for i in range(n):
        c = 0                   
        for j in range(n):
            c += abs(A[i][j])   
        l.append(c)            
    return max(l)              


matrices = [a,b,c,d]
for i, c in zip(matrices, ascii_lowercase):
    print_answer(c, i)
# Out:
#     0   1
# 0  10  15
# 1   0   1
#  Part a - The infinity norm of the above matrix is: 25
#
#     0  1
# 0  10  0
# 1  15  1
#  Part b - The infinity norm of the above matrix is: 16
#
#    0  1  2
# 0  2 -1  0
# 1 -1  2 -1
# 2  0 -1  2
#  Part c - The infinity norm of the above matrix is: 4
#
#    0  1  2
# 0  4 -1  7
# 1 -1  4  0
# 2 -7  0  4
#  Part d - The infinity norm of the above matrix is: 12
