# %%
'''
Name: Animesh Chaudhry 

Class: Math 440

Use the SOR method with ω = 1.2 to solve the linear systems in Exercise 1

'''

# %%
import pandas as pd
from string import ascii_lowercase
from numpy import zeros, diag, diagflat, dot
import numpy as np

# Example Systems in matrix and vector form 
a = [[3, -1, 1],
    [3, 6, 2],
    [3, 3, 7]]
a1 = [1,0,4]

b = [[10, -1, 0],
    [-1, 10, -2],
    [0, -2, 10]]
b1 = [9, 7, 6]

c = [[10, 5, 0, 0],
    [5, 10, -4, 0],
    [0, -4, 8, -1],
    [0, 0, -1, 5]]
c1 = [6,25,-11,11]

d = [[4, 1, -1, 1],
    [1, 4, -1, 1],
    [-1, -1, 5, 4],
    [1, -1, 1, 3]]
d1 = [2,-1,0,1]

e = [[4, 1, 1, 0, 1],
    [-1, -3, 1, 1, 0],
    [2, 1, 5, -1, -1],
    [-1, -1, -1, 4, 0],
    [0, 2, -1, 1, 4]]
e1 = [6,6,6,6,6]

f = [[4, -1, 0, 0, 0, 0],
    [-1, 4, -1, 0, 0, 0],
    [0, -1, 4, 0, 0, 0],
    [0, 0, 0, 4, -1, 0], 
    [0, 0, 0, -1, 4, -1],
    [0, 0, 0, 0, -1, 4 ]]
f1 = [0,5,0,6,-2, 6]

def L_Norm(V):
     
    s = 0
    x = np.array(V)
     
    for i in x:
        s += i**2
    return math.sqrt(s), max(abs(x)) 

def sor(m, w=1.2, x0=None, eps=1e-3, max_itr=100):
  """
  m  : coefficient matrix
  w  : omega
  x0 : initial vector
  eps: tolerance
  max_iter: max iterations 
  
  Returns 
      solution to the system of linear equation
  """
  n  = len(m)
  x0 = [0] * n if x0 == None else x0
  x1 = x0[:]
  itr = 0
  for __ in range(max_itr):
    for i in range(n):
      s = sum(-m[i][j] * x1[j] for j in range(n) if i != j)
      x1[i] = w*(m[i][n]+s)/m[i][i] + (1-w)*x0[i]
    itr+=1
    if all(abs(x1[i]-x0[i]) < eps for i in range(n)):
      return x1, itr
    x0 = x1[:]
  raise ValueError('Solution does not converge')
  




def sor_sol(part, mat):
    print('Part {} ------------------------------------------------\nA = \n{} \n\n Solution from SOR: {}\n\n\n '.format(part, pd.DataFrame(mat), sor(mat)))
    
matrices = [np.c_[a, a1],np.c_[b, b1],np.c_[c, c1],np.c_[d, d1],np.c_[e, e1],np.c_[f, f1]]
for i, c in zip(matrices, ascii_lowercase):
    sor_sol(c, i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-5dcc65bdac84> in <module>
#      84 matrices = [np.c_[a, a1],np.c_[b, b1],np.c_[c, c1],np.c_[d, d1],np.c_[e, e1],np.c_[f, f1]]
#      85 for i, c in zip(matrices, ascii_lowercase):
# ---> 86     sor_sol(c, i)
#
# <ipython-input-16-5dcc65bdac84> in sor_sol(part, mat)
#      80
#      81 def sor_sol(part, mat):
# ---> 82     print('Part {} ------------------------------------------------\nA = \n{} \n\n Solution from SOR: {}\n\n\n '.format(part, pd.DataFrame(mat), sor(mat)))
#      83
#      84 matrices = [np.c_[a, a1],np.c_[b, b1],np.c_[c, c1],np.c_[d, d1],np.c_[e, e1],np.c_[f, f1]]
#
# <ipython-input-16-5dcc65bdac84> in sor(m, w, x0, eps, max_itr)
#      71       x1[i] = w*(m[i][n]+s)/m[i][i] + (1-w)*x0[i]
#      72     itr+=1
# ---> 73     if all(L_Norm(x1[i])-L_Norm(x0[i]) < eps for i in range(n)):
# ...
